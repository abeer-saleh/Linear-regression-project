# %%
from bs4 import BeautifulSoup
import requests
import time, os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium import webdriver

# %%
chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
driver = webdriver.Chrome(chromedriver)
os.environ["webdriver.chrome.driver"] = chromedriver
driver.get('https://sa.aqar.fm/%D9%81%D9%84%D9%84-%D9%84%D9%84%D8%A8%D9%8A%D8%B9/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6')

# %%
response= requests.get("https://sa.aqar.fm/%D9%81%D9%84%D9%84-%D9%84%D9%84%D8%A8%D9%8A%D8%B9/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/%D8%BA%D8%B1%D8%A8-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/%D8%AD%D9%8A-%D8%B7%D9%88%D9%8A%D9%82/%D8%B4%D8%A7%D8%B1%D8%B9-%D8%A7%D9%84%D9%82%D8%A7%D8%B3%D9%85-%D8%A8%D9%86-%D8%B9%D8%A8%D8%AF%D8%A7%D9%84%D9%88%D8%A7%D8%AD%D8%AF-%D8%AD%D9%8A-%D8%B7%D9%88%D9%8A%D9%82-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6-3013648")
#response = requests.get("https://sa.aqar.fm/%D9%81%D9%84%D9%84-%D9%84%D9%84%D8%A8%D9%8A%D8%B9/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6")

# %%
bage_click = driver.find_element_by_xpath('//select[@aria-label="Party size selector"]')
bage_click.click()
time.sleep(1)

# %%
response.status_code
# Out:
# 200

# %%
page = response.text

# %%
page
# Out:
# '<!DOCTYPE html><html><head>\n        <title>فيلا للبيع في شارع القاسم بن عبدالواحد ، حي طويق ، الرياض - 3013648 | تطبيق عقار</title>\n        <meta name="description" content="الواجهة شمال أكثر من 5 غرف نوم شقة صالتان 5 دورات مياه عرض الشارع 15 متر درج صالة غرفة خادمة مؤثثة حوش مطبخ مدخل سيارة المساحة 300 متر مربع  ريال سعودي 1,220,000 اسعد الله اوقاتكم بكل خير\nيوجد لدينا فيلا درج صاله وشقه مساحه ٣٠٠م في حي طويق\nتحت التشطيب قريب من جميع الخدمات والمرافق العامة\nإشراف هندسي على العقار كاملا\nجميع الضمانات المطلوبة على السباكه والعوازل والخزانات والكهرباء والأبواب الإلكترونية\nالدور الأرضي يتكون من مدخل سياره وحوش ومشب ومجلس رجال ومقلط وصاله ومجلس نساء ومطبخ ومستودع وغرفه كبار السن\nالدور الثاني ٤ غرف نوم غرفتين رئيسيه وغرفتين نوم بدوره ميه مشتركه وصاله عائليه\nالدور التالت غرفة ودور ميه مع السطح\nالشقه بمدخل لحالها\nللبيع بالنقد والتقسيط البنكي يوجد لدينا جميع الحلول التمويليه الميسره كما يوجد لدينا تسديد مديونيه وتوفير الدفعة الأولى المقدمه ونتاعمل مع جميع البنوك والشركات التابعة 
# ...

# %%
soup = BeautifulSoup(page, "html")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html><head>
# <title>فيلا للبيع في شارع القاسم بن عبدالواحد ، حي طويق ، الرياض - 3013648 | تطبيق عقار</title>
# <meta content="الواجهة شمال أكثر من 5 غرف نوم شقة صالتان 5 دورات مياه عرض الشارع 15 متر درج صالة غرفة خادمة مؤثثة حوش مطبخ مدخل سيارة المساحة 300 متر مربع  ريال سعودي 1,220,000 اسعد الله اوقاتكم بكل خير
# يوجد لدينا فيلا درج صاله وشقه مساحه ٣٠٠م في حي طويق
# تحت التشطيب قريب من جميع الخدمات والمرافق العامة
# إشراف هندسي على العقار كاملا
# جميع الضمانات المطلوبة على السباكه والعوازل والخزانات والكهرباء والأبواب الإلكترونية
# الدور الأرضي يتكون من مدخل سياره وحوش ومشب ومجلس رجال ومقلط وصاله ومجلس نساء ومطبخ ومستودع وغرفه كبار السن
# الدور الثاني ٤ غرف نوم غرفتين رئيسيه وغرفتين نوم بدوره ميه مشتركه وصاله عائليه
# الدور التالت غرفة ودور ميه مع السطح
# الشقه بمدخل لحالها
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    فيلا للبيع في شارع القاسم بن عبدالواحد ، حي طويق ، الرياض - 3013648 | تطبيق عقار
#   </title>
#   <meta content="الواجهة شمال أكثر من 5 غرف نوم شقة صالتان 5 دورات مياه عرض الشارع 15 متر درج صالة غرفة خادمة مؤثثة حوش مطبخ مدخل سيارة المساحة 300 متر مربع  ريال سعودي 1,220,000 اسعد الله اوقاتكم بكل خير
# يوجد لدينا فيلا درج صاله وشقه مساحه ٣٠٠م في حي طويق
# تحت التشطيب قريب من جميع الخدمات والمرافق العامة
# إشراف هندسي على العقار كاملا
# جميع الضمانات المطلوبة على السباكه والعوازل والخزانات والكهرباء والأبواب الإلكترونية
# الدور الأرضي يتكون من مدخل سياره وحوش ومشب ومجلس رجال ومقلط وصاله ومجلس نساء ومطبخ ومستودع وغرفه كبار السن
# الدور الثاني ٤ غرف نوم غرفتين رئيسيه وغرفتين نوم بدوره ميه مشتركه وصاله عائليه
# الدور التالت غرفة ودور ميه مع السطح
# الشقه بمدخل لحالها
# ...

# %%
list = soup.find_all("div")

# %%
# how many containers?
len(list)
# Out:
# 192

# %%
areas = []
prices = []
direction = []
bed = []
path = []
living = []
steetwidth = []
oldness = []
views = []

# %%
areas.append(soup.find(text="المساحة").find_previous().find_previous().find_previous().text)
direction.append(soup.find(text="الواجهة").find_previous().find_previous().find_previous().text)
bed.append(soup.find(text="غرف النوم").find_previous().find_previous().find_previous().text)
living.append(soup.find(text="الصالات").find_previous().find_previous().find_previous().text)
path.append(soup.find(text="دورات مياه").find_previous().find_previous().find_previous().text)
steetwidth.append(soup.find(text="عرض الشارع").find_previous().find_previous().find_previous().text)
oldness.append(soup.find(text="عمر العقار").find_previous().find_previous().find_previous().text)
views.append(soup.find("table", class_="dc-listingInfoTable").find("span").text) #views
prices.append(soup.find("span", class_="listingPagePrice").find("span").findNext().text) #price

# %%
e = soup.findChild('table',class_='dc-detailsTable') 
e.prettify()
# Out:
# '<table class="dc-detailsTable">\n <tbody>\n  <tr>\n   <td align="right" dir="rtl">\n    <div style="width:30px;display:inline-block;margin-left:6px">\n    </div>\n    420 م²\n   </td>\n   <td align="right" dir="rtl">\n    المساحة\n   </td>\n  </tr>\n  <tr>\n   <td align="right" dir="rtl">\n    <div style="width:30px;display:inline-block;margin-left:6px">\n    </div>\n    شمال شرقي\n   </td>\n   <td align="right" dir="rtl">\n    الواجهة\n   </td>\n  </tr>\n  <tr>\n   <td align="right" dir="rtl">\n    <div style="width:30px;display:inline-block;margin-left:6px">\n    </div>\n    3\n   </td>\n   <td align="right" dir="rtl">\n    غرف النوم\n   </td>\n  </tr>\n  <tr>\n   <td align="right" dir="rtl">\n    <div style="width:30px;display:inline-block;margin-left:6px">\n    </div>\n    3\n   </td>\n   <td align="right" dir="rtl">\n    دورات مياه\n   </td>\n  </tr>\n  <tr>\n   <td align="right" dir="rtl">\n    <div style="width:30px;display:inline-block;margin-left:6px">\n    </div>\n    20 م
# ...

# %%
areas.append(e.find("td").text)
prices.append(e.find("td").text)
direction.append(e.find("td").text)
bed.append(e.find("td").text)
path.append(e.find("td").text)
living.append(e.find("td").text)
steetwidth.append(e.find("td").text)
oldness.append(e.find("td").text)
views.append(e.find("td").text)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-154-3c694796f360> in <module>
#       1 areas.append(e.find("td").text)
# ----> 2 prices.append(e.find("td")[1].text)
#       3 direction.append(e.find("td").text)
#       4 bed.append(e.find("td").text)
#       5 path.append(e.find("td").text)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/element.py in __getitem__(self, key)
#    1404         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1405         and throws an exception if it's not there."""
# -> 1406         return self.attrs[key]
#    1407
#    1408     def __iter__(self):
#
# KeyError: 1

# %%
prices
# Out:
# ['420 م²', 'المساحة']
